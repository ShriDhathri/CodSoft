# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sales_data = pd.read_csv(r"C:\Users\a\Downloads\advertising.csv")
sales_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [raw]
# To display the top 10 rows

# %%
sales_data.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# To check the number of rows and columns

# %%
sales_data.shape
# Out:
# (200, 4)

# %%
sales_data.isnull().values.any() #To check the null values
# Out:
# False

# %%
sales_data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sns.heatmap(sales_data.isnull())
# Out:
# <Axes: >

# %%
#In order to check the missing values
missing = sales_data.isnull().sum()*100/len(sales_data)
missing
# Out:
# TV           0.0
# Radio        0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %%
#To check wheather any duplicate values present
sales_data.duplicated().any()
# Out:
# False

# %%
sales_data.describe(include='all')
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales_data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
#Sorting the table based on Sales in Descending Order
sort=sales_data.loc[sales_data['Sales'].sort_values(ascending=False)[:10].index]
sort
# Out:
#         TV  Radio  Newspaper  Sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 147  243.2   49.0       44.3   25.4
# 98   289.7   42.3       51.2   25.4
# 36   266.9   43.8        5.0   25.4
# 128  220.3   49.0        3.2   24.7
# 17   281.4   39.6       55.8   24.4
# 61   261.3   42.7       54.7   24.2
# 101  296.4   36.3      100.9   23.8

# %%
sns.pairplot(sales_data,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')
plt.show()

# %%
sns.barplot(sales_data,x="TV",y="Sales",estimator="sum",errorbar=None)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\a\Downloads\advertising.csv")
sns.barplot(x='Radio',
            y='Sales',
            data=df)
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20,18), dpi=80, facecolor='w', edgecolor='r')
sns.barplot(x="Sales", y = "Newspaper" , data = df)
plt.show()

# %%
#To visualize the sales of the TV,Radio, Newspaper using scatterplot and barcharts
import seaborn as sns
sns.pairplot(sales_data)
plt.show()

# %%
pip install --upgrade seaborn pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
#Correlation heatmap is used in order to graphically represent the pairwise correlation between variables in the dataset
sns.heatmap(sales_data.corr(),annot = True)
plt.show()

# %% [markdown]
# From The above Correlation Heatmap we can say that TV advertising has the stronest impact on sales, followed by Radio and Newspaper which have moderate to weak effects

# %% [markdown]
# Training and Testing of data of TV as it has the strongest imapct on Sales

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['TV'],df['Sales'])

# %% [markdown]
# From the above graph we can see that TV is in linear Regression with Sales now we can train and test the data

# %%
plt.scatter(df['Radio'],df['Sales'])

# %% [markdown]
# As we can see from the above graph it is not in linear regression hence we have not included Radio and the same applies to Newspaper

# %%
X=df[['TV']]
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
len(X_train)
# Out:
# 160

# %%
len(X_test)
# Out:
# 40

# %%
X_train
# Out:
#         TV
# 190   39.5
# 7    120.2
# 26   142.9
# 138   43.0
# 58   210.8
# ..     ...
# 113  209.6
# 64   131.1
# 15   195.4
# 125   87.2
# 9    199.8
#
# [160 rows x 1 columns]

# %%
X_test
# Out:
#         TV
# 59   210.7
# 5      8.7
# 20   218.4
# 198  283.6
# 52   216.4
# 19   147.3
# 162  188.4
# 55   198.9
# 69   216.8
# 2     17.2
# 98   289.7
# 10    66.1
# 75    16.9
# 142  220.5
# 124  229.5
# 63   102.7
# 109  255.4
# 78     5.4
# 111  241.7
# 185  205.0
# 154  187.8
# 130    0.7
# 61   261.3
# 87   110.7
# 102  280.2
# 121   18.8
# 136   25.6
# 1     44.5
# 47   239.9
# 172   19.6
# 159  131.7
# 39   228.0
# 76    27.5
# 91    28.6
# 35   290.7
# 178  276.7
# 127   80.2
# 169  284.3
# 46    89.7
# 174  222.4

# %%
y_train
# Out:
# 190    10.8
# 7      13.2
# 26     15.0
# 138     9.6
# 58     23.8
#        ...
# 113    20.9
# 64     16.0
# 15     22.4
# 125    10.6
# 9      15.6
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 59     18.4
# 5       7.2
# 20     18.0
# 198    25.5
# 52     22.6
# 19     14.6
# 162    19.9
# 55     23.7
# 69     22.3
# 2      12.0
# 98     25.4
# 10     12.6
# 75      8.7
# 142    20.1
# 124    19.7
# 63     14.0
# 109    19.8
# 78      5.3
# 111    21.8
# 185    22.6
# 154    20.6
# 130     1.6
# 61     24.2
# 87     16.0
# 102    19.8
# 121     7.0
# 136     9.5
# 1      10.4
# 47     23.2
# 172     7.6
# 159    12.9
# 39     21.5
# 76      6.9
# 91      7.3
# 35     17.8
# 178    16.8
# 127    11.9
# 169    20.0
# 46     10.6
# 174    16.5
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train,y_train)  #Here fit method is used in order to train the model
# Out:
# LinearRegression()

# %%
X_test
# Out:
#         TV
# 59   210.7
# 5      8.7
# 20   218.4
# 198  283.6
# 52   216.4
# 19   147.3
# 162  188.4
# 55   198.9
# 69   216.8
# 2     17.2
# 98   289.7
# 10    66.1
# 75    16.9
# 142  220.5
# 124  229.5
# 63   102.7
# 109  255.4
# 78     5.4
# 111  241.7
# 185  205.0
# 154  187.8
# 130    0.7
# 61   261.3
# 87   110.7
# 102  280.2
# 121   18.8
# 136   25.6
# 1     44.5
# 47   239.9
# 172   19.6
# 159  131.7
# 39   228.0
# 76    27.5
# 91    28.6
# 35   290.7
# 178  276.7
# 127   80.2
# 169  284.3
# 46    89.7
# 174  222.4

# %%
clf.predict(X_test) #Predicted values of the X test for these data
# Out:
# array([18.52447456,  7.47083999, 18.94582598, 22.51363279, 18.83638405,
#        15.05516549, 17.30419708, 17.8787672 , 18.85827244,  7.93596817,
#        22.84743066, 10.61182328,  7.91955188, 19.06074   , 19.55322867,
#        12.61461053, 20.97050162,  7.29026081, 20.22082443, 18.21256507,
#        17.27136451,  7.03307228, 21.29335531, 13.05237824, 22.32758151,
#         8.02352171,  8.39562426,  9.42985047, 20.12232669,  8.06729848,
#        14.20151847, 19.47114723,  8.49959409,  8.55978715, 22.90215163,
#        22.13605814, 11.38338886, 22.55193746, 11.90323801, 19.16470983])

# %%
y_test
# Out:
# 59     18.4
# 5       7.2
# 20     18.0
# 198    25.5
# 52     22.6
# 19     14.6
# 162    19.9
# 55     23.7
# 69     22.3
# 2      12.0
# 98     25.4
# 10     12.6
# 75      8.7
# 142    20.1
# 124    19.7
# 63     14.0
# 109    19.8
# 78      5.3
# 111    21.8
# 185    22.6
# 154    20.6
# 130     1.6
# 61     24.2
# 87     16.0
# 102    19.8
# 121     7.0
# 136     9.5
# 1      10.4
# 47     23.2
# 172     7.6
# 159    12.9
# 39     21.5
# 76      6.9
# 91      7.3
# 35     17.8
# 178    16.8
# 127    11.9
# 169    20.0
# 46     10.6
# 174    16.5
# Name: Sales, dtype: float64

# %%
clf.score(X_test,y_test)  #Here I'm comparing the X and Y test values to get the ACCURACY
# Out:
# 0.8176242999443031

# %% [markdown]
# Hence the Accuracy of the Data is 81%
