# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
movie_data = pd.read_csv(r"C:\Users\a\Downloads\archive\IMDb Movies India.csv",encoding='ISO-8859-1')
movie_data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019.0  109 min            Drama
# 2                             #Homecoming  2021.0   90 min   Drama, Musical
# 3                                 #Yaaram  2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again  2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  1988.0      NaN           Action
# 15505                               Zulmi  1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj  2005.0      NaN           Action
# 15507                       Zulmi Shikari  1988.0      NaN           Action
# 15508                        Zulm-O-Sitam  1998.0  130 min    Action, Drama
#
# ...

# %% [markdown]
# To display the top 6 rows

# %%
movie_data.head(6)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  2019.0  109 min
# 2                         #Homecoming  2021.0   90 min
# 3                             #Yaaram  2019.0  110 min
# 4                   ...And Once Again  2010.0  105 min
# 5                ...Aur Pyaar Ho Gaya  1997.0  147 min
#
#                     Genre  Rating Votes            Director       Actor 1  \
# 0                   Drama     NaN   NaN       J.S. Randhawa      Manmauji
# 1                   Drama     7.0     8       Gaurav Bakshi  Rasika Dugal
# 2          Drama, Musical     NaN   NaN  Soumyajit Majumdar  Sayani Gupta
# 3         Comedy, Romance     4.4    35          Ovais Khan       Prateik
# 4                   Drama     NaN   NaN        Amol Palekar  Rajat Kapoor
# 5  Comedy, Drama, Musical     4.7   827        Rahul Rawail    Bobby Deol
#
#                   Actor 2          Actor 3
# ...

# %%
movie_data.tail(10)
# Out:
#                       Name    Year Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab  1995.0      NaN                Action     NaN
# 15500      Zulm Ka Muqabla  1993.0      NaN                Action     NaN
# 15501      Zulm Ki Hukumat  1992.0      NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar  1979.0      NaN                Action     NaN
# 15503      Zulm Ki Zanjeer  1989.0  125 min  Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga  1988.0      NaN                Action     4.6
# 15505                Zulmi  1999.0  129 min         Action, Drama     4.5
# 15506            Zulmi Raj  2005.0      NaN                Action     NaN
# 15507        Zulmi Shikari  1988.0      NaN                Action     NaN
# 15508         Zulm-O-Sitam  1998.0  130 min         Action, Drama     6.2
#
#       Votes           Director                Actor 1              Actor 2  \
# 15499   NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# To count the number of Rows and columns

# %%
movie_data.shape
# Out:
# (15509, 10)

# %% [markdown]
# In order to check the missing values in the Dataset

# %%
movie_data.isnull().values.any()
# Out:
# True

# %% [markdown]
# By displaying the True it shows there are missing datas

# %%
movie_data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
#Using seaborn heatmap we can visualize the missing values by passing the pandas parametere
sns.heatmap(movie_data.isnull())
#these white lines represent the missing values in the data
# Out:
# <Axes: >

# %%
#In order to check the number of missing values in the data
per_missing = movie_data.isnull().sum() * 100/len(movie_data)
per_missing
# Out:
# Name         0.000000
# Year         3.404475
# Duration    53.317429
# Genre       12.102650
# Rating      48.939326
# Votes       48.932878
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %%
#axis = 0 means drop the rows which contains the missing values
#axis = 1 means drop the columns which contain the missing values
movie_data.dropna(axis=0)
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019.0  109 min
# 3                                 #Yaaram  2019.0  110 min
# 5                    ...Aur Pyaar Ho Gaya  1997.0  147 min
# 6                               ...Yahaan  2005.0  142 min
# 8                      ?: A Question Mark  2012.0   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  2015.0  115 min
# 15494                            Zubeidaa  2001.0  153 min
# 15503                     Zulm Ki Zanjeer  1989.0  125 min
# 15505                               Zulmi  1999.0  129 min
# 15508                        Zulm-O-Sitam  1998.0  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %% [markdown]
# In order to check the duplicate data present in the Dataset

# %%
movie_data.duplicated().any()
#False indicates that no duplicate values are +nt 
#True indicates that dup values are there
# Out:
# True

# %%
#To get the total description of the data
movie_data.describe(include='all')
# include ='all' helps to describe the values of numerical as well as categorical
# Out:
#           Name          Year Duration  Genre       Rating Votes      Director  \
# count    15509  14981.000000     7240  13632  7919.000000  7920         14984
# unique   13838           NaN      182    485          NaN  2034          5938
# top     Anjaam           NaN  120 min  Drama          NaN     8  Jayant Desai
# freq         7           NaN      240   2780          NaN   227            58
# mean       NaN   1987.012215      NaN    NaN     5.841621   NaN           NaN
# std        NaN     25.416689      NaN    NaN     1.381777   NaN           NaN
# min        NaN   1913.000000      NaN    NaN     1.100000   NaN           NaN
# 25%        NaN   1968.000000      NaN    NaN     4.900000   NaN           NaN
# 50%        NaN   1991.000000      NaN    NaN     6.000000   NaN           NaN
# 75%        NaN   2009.000000      NaN    NaN     6.800000   NaN           NaN
# max        NaN   2022.000000      NaN    NaN    10.000000   NaN           NaN
#
# ...

# %%
movie_data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
movie_data = movie_data.dropna()

# %%
movie_data.describe()
# Out:
#               Year       Rating
# count  5659.000000  5659.000000
# mean   1996.247570     5.898533
# std      19.741839     1.381165
# min    1931.000000     1.100000
# 25%    1983.000000     5.000000
# 50%    2002.000000     6.100000
# 75%    2013.000000     6.900000
# max    2021.000000    10.000000

# %%
movie_data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %% [markdown]
# Top 10 movies

# %%
top_movie = movie_data.loc[movie_data['Rating'].sort_values(ascending = False)[:10].index]
top_movie
# Out:
#                       Name    Year Duration                         Genre  \
# 8339       Love Qubool Hai  2020.0      NaN                Drama, Romance
# 5410            Half Songs  2021.0      NaN                Music, Romance
# 6852                  June  2021.0      NaN                         Drama
# 14222  The Reluctant Crime  2020.0      NaN                         Drama
# 5077          Gho Gho Rani  2019.0      NaN              History, Romance
# 1314          Ashok Vatika  2018.0      NaN                         Drama
# 13231           Sindhustan  2019.0      NaN  Documentary, Family, History
# 8344          Love Sorries  2021.0      NaN        Comedy, Drama, Romance
# 12673   Secrets of Sinauli  2021.0      NaN          Documentary, History
# 11843              Refl3ct  2021.0      NaN                        Sci-Fi
#
#        Rating  Votes         Director            Actor 1          Actor 2  \
# 8339     10.0    5.0  Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# ...

# %%
# Convert 'Duration' to string first, then remove ' min' and strip whitespace
movie_data.loc['Duration'] = movie_data['Duration'].astype(str).str.replace(' min', '').str.strip()

# Convert the 'Duration' column to numeric, forcing invalid entries to NaN
movie_data.loc[:, 'Duration'] = pd.to_numeric(movie_data['Duration'], errors='coerce')

# Filter the movies with 'Duration' of 180 minutes or more
long_movies = movie_data[movie_data['Duration'] >= 180]

# Display the 'Title' of the filtered movies
print(long_movies['Name'])
# Out:
# Series([], Name: Name, dtype: object)

# %% [markdown]
# Highest avg Voting

# %%
movie_data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
movie_data.loc[:, 'Votes'] = pd.to_numeric(movie_data['Votes'], errors='coerce')
movie_data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2003.0    260.987179
# 2008.0    260.190476
# 2010.0    258.540541
# 2009.0    256.443038
# 2002.0        253.45
#              ...
# 1933.0          12.0
# 1932.0          12.0
# 1938.0          10.6
# 1939.0           9.5
# 1934.0           8.5
# Name: Votes, Length: 91, dtype: object

# %%
sns.barplot(x='Year',y='Votes',data=movie_data)
plt.title("Votes By Year")
# Out:
# Text(0.5, 1.0, 'Votes By Year')

# %%
genre_counts = movie_data['Genre'].value_counts().reset_index()
genre_counts.columns = ['Genre', 'Count']

# Select the top N genres (e.g., top 5)
top_n_genres = genre_counts.head(5)
top_n_genres
# Out:
#              Genre  Count
# 0            Drama     13
# 1   Drama, Romance      5
# 2    Drama, Family      2
# 3    Comedy, Drama      2
# 4  Drama, Thriller      2

# %%
plt.figure(figsize=(4, 4))
plt.pie(top_n_genres['Count'], labels=top_n_genres['Genre'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Movie Genre Distribution', fontsize=16)
plt.axis('equal')
plt.show()
